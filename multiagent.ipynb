# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing advancements are set to revolutionize AI by overcoming the computational limits of classical systems. Key developments include:
#
# *   **Quantum Machine Learning (QML):** New QML techniques are emerging that promise to significantly speed up AI's learning processes and improve model effectiveness, even in areas like semiconductor design.
# *   **Enhanced Data Processing:** Quantum computers can handle and classify large datasets more efficiently, leading to faster and more accurate pattern recognition for AI. They also excel at complex optimization problems.
# *   **Quantum AI Systems:** The convergence of quantum computing and AI, termed Quantum AI, is expected to enable the solution of problems currently beyond classical capabilities, with potential breakthroughs in personalized medicine and logistics optimization.
# *   **Synergistic Advancements:** Quantum computing can address AI's intensive computational and data needs, while AI is being used to enhance the reliability and performance of quantum systems, accelerating the development of fault-tolerant quantum computers.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Multi-Agent Systems: Your Software's Next Superpower
#
# Are you tired of wrestling with monolithic codebases that are impossible to maintain? Do you dream of building intelligent, adaptable software that can tackle complex problems with ease? If so, it's time to explore the transformative world of Multi-Agent Systems (MAS). This isn't just another buzzword; it's a powerful paradigm shift that can unlock unprecedented capabilities for your software development projects.
#
# ### 1. Decomposing Complexity: Divide and Conquer, Smarter
#
# *   **Breaking Down the Beast:** MAS allows you to break down large, intricate problems into smaller, more manageable units called agents. Each agent can focus on a specific task or domain, leading to cleaner, more modular code.
# *   **Specialization for Efficiency:** Just like a well-oiled team, agents can be specialized. This means you can assign developers to specific agents, allowing them to become experts in a particular area, boosting productivity and reducing cognitive load.
# *   **Easier Debugging and Maintenance:** When issues arise, you can often isolate them to a specific agent, making debugging a far less daunting task. Maintenance becomes a matter of updating or replacing individual agents rather than sifting through a giant, interconnected system.
#
# ### 2. Fostering Collaboration: The Power of Collective Intelligence
#
# *   **Agents Working Together:** The core strength of MAS lies in the ability of agents to communicate and coordinate. They can share information, negotiate tasks, and collectively work towards a common goal, much like human teams.
# *   **Emergent Behavior:** When agents interact, complex and intelligent behaviors can emerge that weren't explicitly programmed into any single agent. This can lead to novel solutions and surprising adaptability in your software.
# *   **Resource Optimization:** Agents can dynamically allocate and share resources, ensuring that tasks are performed efficiently. This is particularly useful in distributed systems where resources might be scarce or fluctuating.
#
# ### 3. Enhancing Adaptability and Resilience: Building Software That Bounces Back
#
# *   **Dynamic Reconfiguration:** If one agent fails or encounters an unexpected situation, other agents can take over its responsibilities or adapt their behavior to compensate. This makes your system significantly more resilient to failures.
# *   **Learning and Evolution:** Agents can be designed to learn from their experiences and adapt their strategies over time. This allows your software to evolve and improve its performance without constant manual intervention.
# *   **Handling Uncertainty:** MAS is well-suited for environments where information is incomplete or unreliable. Agents can make decisions based on partial information and adapt their plans as new data becomes available.
#
# ### 4. Unlocking New Possibilities: Beyond Traditional Software
#
# *   **Simulations and Modeling:** MAS is ideal for creating realistic simulations of complex systems, from traffic flow to economic markets. This allows for better understanding and prediction of real-world phenomena.
# *   **Intelligent Automation:** Imagine automating complex workflows where different components need to interact intelligently. MAS can drive sophisticated automation in areas like robotics, logistics, and customer service.
# *   **Personalized Experiences:** By understanding individual user needs and preferences through dedicated agents, MAS can deliver highly personalized software experiences.
#
# ### Conclusion: Embrace the Future of Intelligent Software
#
# Multi-Agent Systems offer a powerful and flexible approach to software development. By embracing this paradigm, you can build systems that are not only more robust and maintainable but also more intelligent, adaptable, and capable of solving problems that were once considered intractable. It's time to give your software a superpower – explore the world of MAS and unlock its incredible potential.
# WriterAgent > ## Your Software's Next Superpower: Unleashing the Potential of Multi-Agent Systems
#
# Are you finding yourself bogged down by monolithic codebases? Do you yearn for software that's not just functional, but truly intelligent and adaptable? Then it's time to dive into the exciting realm of Multi-Agent Systems (MAS). This isn't just a technical trend; it's a paradigm shift that can revolutionize how we build software.
#
# At its core, MAS is about **decomposition**. Instead of a single, unwieldy system, you break down complex problems into smaller, specialized units – agents. Think of it as assembling a crack team where each member has a specific role. This modularity makes code cleaner, debugging a breeze (you can often isolate issues to a single agent), and maintenance a far less painful experience. Developers can even specialize in particular agents, boosting efficiency and reducing cognitive load.
#
# But MAS isn't just about breaking things down; it's about **collaboration**. Agents communicate, negotiate, and coordinate to achieve common goals. This collective intelligence can lead to emergent behaviors – sophisticated actions not explicitly programmed into any single agent, offering surprising adaptability. Plus, agents can intelligently manage and share resources, optimizing performance, especially in distributed environments.
#
# Finally, MAS builds software that's incredibly **resilient and adaptable**. If one agent falters, others can step in. Agents can learn from experience, evolving their strategies and improving performance over time. This makes your software more robust, capable of handling uncertainty and evolving alongside your needs. Ready to build smarter, more powerful software? Explore MAS!
# EditorAgent > ## Your Software's Next Superpower: Unleashing the Potential of Multi-Agent Systems
#
# Are you tired of wrestling with monolithic codebases that feel impossible to maintain? Do you dream of building software that's not just functional, but truly intelligent and adaptable? If so, it's time to dive into the exciting realm of Multi-Agent Systems (MAS). This isn't just another technical trend; it's a paradigm shift that can revolutionize how we build software.
#
# At its core, MAS is about **decomposition**. Instead of a single, unwieldy system, you break down complex problems into smaller, specialized units – agents. Think of it as assembling a crack team where each member has a specific role. This modularity leads to cleaner code, makes debugging a breeze (you can often isolate issues to a single agent), and transforms maintenance from a chore into a far less painful experience. Developers can even specialize in particular agents, boosting efficiency and reducing cognitive load.
#
# But MAS isn't just about breaking things down; it's about **collaboration**. Agents communicate, negotiate, and coordinate to achieve common goals. This collective intelligence can lead to emergent behaviors – sophisticated actions not explicitly programmed into any single agent, offering surprising adaptability. Furthermore, agents can intelligently manage and share resources, optimizing performance, especially in distributed environments.
#
# Finally, MAS enables the creation of software that's incredibly **resilient and adaptable**. If one agent falters, others can step in to take over its responsibilities. Agents can learn from experience, evolving their strategies and improving performance over time. This makes your software more robust, capable of handling uncertainty and evolving alongside your needs.
#
# Ready to build smarter, more powerful software? Explore MAS!

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a concise executive briefing on recent breakthroughs:
#
# **Health:** Gene therapy is showing promise for genetic diseases, with applications expanding to blindness and other conditions. Within two years, at-home tests for COVID, flu, and potentially RSV could be widely available, aiding faster diagnosis and treatment.
#
# **Technology:** AI democratization is making advanced tools accessible to SMEs, fostering rapid innovation. Quantum computing, though in early pilot stages, holds potential for complex problem-solving, with tangible business impacts expected in the longer term.
#
# **Finance:** Embedded finance is integrating financial services into non-financial platforms, projected for significant growth by 2026. AI-driven personalization is transforming financial services, with the AI market in this sector already exceeding $115 billion.
# TechResearcher > **Key AI/ML Trends in 2025:**
#
# 1.  **Generative AI Expansion & Multimodal Models:** Generative AI, exemplified by models like Google's Gemini, is moving beyond text to create complex content across images, video, and audio. Multimodal AI integrates various data types (text, image, audio, video) for more nuanced understanding and interaction. Companies like Google (Gemini, Imagen, Veo) and Microsoft (Azure AI) are major players. The impact is enhanced creativity, personalized experiences, and more intuitive human-computer interfaces.
#
# 2.  **Agentic AI and Automation:** Agentic AI systems are becoming capable of completing full tasks with minimal human input. This trend focuses on automating complex processes, from software development to customer service. Companies such as Microsoft are actively building agentic ecosystems. The impact includes increased efficiency, cost reduction, and freeing up human workers for more complex, creative tasks.
#
# 3.  **Specialized/Domain-Specific Models & SLMs:** The trend is shifting towards smaller, specialized AI models (SLMs) that outperform larger, general models in specific industries. These domain-specific models, powered by tailored data, offer greater accuracy and efficiency. Google (Vertex AI, domain-specific AI models) and Databricks are key in this area. This leads to more precise AI applications in sectors like healthcare and finance, driving significant business value.
# FinanceResearcher > **Tech Executive Briefing:**
#
# **Key Trends:**
# 1.  **AI Governance and Trust:** Building trust in AI adoption through clear oversight, model risk controls, and transparent communication with users is paramount.
# 2.  **Cybersecurity:** Increased focus on robust security measures is essential as technology integration deepens across sectors.
# 3.  **Next-Generation Technologies:** Exploring and implementing emerging tech like 5G, IoT, and advanced networking solutions to drive innovation and business transformation.
#
# **Market Implications:** Companies that effectively implement AI governance and prioritize cybersecurity will gain a competitive advantage and foster user confidence. Early adoption of next-gen technologies will unlock new efficiencies and market opportunities.
#
# **Future Outlook:** The tech landscape will continue to be shaped by AI's evolving role and the critical need for secure, innovative solutions. Expect a surge in AI-powered tools and a heightened emphasis on data privacy and security protocols.
#
# **Health Executive Briefing:**
#
# **Key Trends:**
# 1.  **AI in Clinical Settings:** AI is being integrated for documentation assistance, decision support, and care coordination, improving efficiency and outcomes.
# 2.  **Value-Based Care (VBC) and Outcomes-Based Compensation (OBC):** Healthcare providers are increasingly adopting VBC models, requiring a focus on health literacy, plain language, and cultural competence to improve patient results.
# 3.  **Workforce Resilience and Leadership:** Strategies to enhance employee well-being, engagement, and leadership skills are crucial for navigating strain and budget finalizations.
#
# **Market Implications:** Healthcare organizations embracing AI and VBC models will see improved operational efficiency and better patient outcomes. Investing in workforce development will be key to retaining talent and ensuring quality care.
#
# **Future Outlook:** The healthcare sector will see deeper AI integration and a continued shift towards value-driven care. Emphasis will be placed on data-driven decision-making, improving patient engagement, and building resilient healthcare workforces.
#
# **Finance Executive Briefing:**
#
# **Key Trends:**
# 1.  **AI and Pricing Conundrum:** Balancing AI's cost and client expectations with productivity gains is a growing challenge.
# 2.  **Economic Uncertainty and Geopolitical Chaos:** Navigating volatile economic landscapes and global instability is a top priority.
# 3.  **Business Transformation and System Overhaul:** Firms are increasingly focused on overhauling legacy systems and driving digital transformation.
#
# **Market Implications:** Financial institutions must adapt to AI-driven pricing models and build resilience against economic fluctuations. Investing in modernizing IT infrastructure is critical for efficiency and competitive positioning.
#
# **Future Outlook:** The finance industry will continue to grapple with the impact of AI on service delivery and pricing. Strategic agility and a focus on technological modernization will be essential for sustained profitability and navigating complex global markets.
# AggregatorAgent > ## Executive Summary: Converging Trends in Technology, Health, and Finance
#
# **Key Takeaways:**
#
# Artificial Intelligence (AI) is the dominant force reshaping all three sectors, driving innovation and demanding strategic adaptation. Generative and agentic AI are expanding capabilities, while a shift towards specialized, domain-specific models is unlocking greater precision and value. Cybersecurity and AI governance are critical for building trust and mitigating risks across industries.
#
# **Surprising Connections:**
#
# The democratization of AI is fueling rapid innovation in both technology and healthcare, enabling Small and Medium-sized Enterprises (SMEs) and improving patient care through AI-driven clinical tools and advanced diagnostics. Similarly, AI's impact on personalization is transforming both financial services and patient engagement in healthcare, while embedded finance is integrating financial services into everyday platforms, mirroring the broader trend of technology integration across sectors.
#
# **Most Important Insights:**
#
# *   **AI's pervasive influence:** From generative content creation and task automation to clinical decision support and financial personalization, AI is fundamental to future advancements.
# *   **Specialization yields value:** Domain-specific AI models offer superior accuracy and efficiency, driving significant business impact in tailored applications.
# *   **Trust and security are paramount:** Robust AI governance, cybersecurity, and data privacy protocols are essential for widespread adoption and competitive advantage.
# *   **Resilience is key:** Navigating economic uncertainty and workforce challenges requires strategic agility and investment in modernizing systems and developing talent.
#
# The future demands proactive adoption of secure, AI-powered solutions, a focus on specialized applications, and a commitment to building resilient organizations capable of adapting to rapid technological and global shifts.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# HealthResearcher > The salt spray kissed Silas’s weathered face as he ascended the winding stairs of the lighthouse. For thirty years, the beam had been his sole companion, cutting through the inky blackness of the sea. Tonight, however, felt different. A peculiar shimmer, not of moonlight, caught his eye in the dusty storeroom. Nestled amongst forgotten charts lay a map, not of parchment, but of a material that pulsed with an ethereal, blue-green light. Intricate lines, unlike any he’d seen, swirled across its surface, seemingly charting unseen currents and celestial alignments. As his calloused fingers traced a glowing constellation, the map hummed, and a faint warmth spread through the room. Silas, a man of routine and solitude, felt a thrill of the unknown awaken within him. He knew, with a certainty that defied logic, that this was no ordinary chart. It was a guide, a whisper from a world beyond the horizon, and he, the solitary keeper, had stumbled upon its secret.
# FinanceResearcher > **Key Fintech Trends Shaping the Future:**
#
# Three prominent fintech trends are reshaping the financial landscape: **Artificial Intelligence (AI)**, **Embedded Finance**, and **Blockchain/Decentralized Finance (DeFi)**.
#
# **Market Implications:**
# *   **AI** is driving efficiency and personalization, aiding in fraud detection and regulatory compliance.
# *   **Embedded Finance** integrates financial services into non-financial platforms, expanding customer reach and engagement.
# *   **Blockchain/DeFi** promises faster, more secure, and transparent transactions, with a growing prediction of 10% of global GDP being tokenized by 2027.
#
# **Future Outlook:**
# These trends are expected to continue their rapid evolution, with the global fintech market projected for significant growth. While AI's transformative power is increasingly evident, regulatory oversight is also intensifying, pushing for greater compliance and consumer data protection. The future points towards a more integrated, intelligent, and decentralized financial ecosystem.
# TechResearcher > Recent AI/ML trends are focusing on **Generative AI**, **AI in Drug Discovery**, and **AI in Robotics**.
#
# **Generative AI** is seeing rapid advancement, with companies like **OpenAI**, **Microsoft**, and **Google** leading development. Its impact is widespread, transforming creative industries by enabling new forms of content creation while also raising ethical concerns about job displacement and intellectual property.
#
# **AI in Drug Discovery** is revolutionizing the pharmaceutical industry. Companies such as **BenevolentAI**, **Insilico Medicine**, and **Recursion Pharmaceuticals** are using AI to accelerate the identification of drug candidates and predict treatment efficacy. This trend promises faster, more cost-effective development of new medicines.
#
# **AI in Robotics** is enhancing automation across various sectors. Major players like **ABB**, **Fanuc**, and **Boston Dynamics** are integrating AI to create more adaptable and intelligent robots for manufacturing, logistics, and healthcare. This development is boosting efficiency and safety, though it also sparks discussions about workforce impact.
# AggregatorAgent > The salt spray kissed Silas’s weathered face as he ascended the winding stairs of the lighthouse. For thirty years, the beam had been his sole companion, cutting through the inky blackness of the sea. Tonight, however, felt different. A peculiar shimmer, not of moonlight, caught his eye in the dusty storeroom. Nestled amongst forgotten charts lay a map, not of parchment, but of a material that pulsed with an ethereal, blue-green light. Intricate lines, unlike any he’d seen, swirled across its surface, seemingly charting unseen currents and celestial alignments. As his calloused fingers traced a glowing constellation, the map hummed, and a faint warmth spread through the room. Silas, a man of routine and solitude, felt a thrill of the unknown awaken within him. He knew, with a certainty that defied logic, that this was no ordinary chart. It was a guide, a whisper from a world beyond the horizon, and he, the solitary keeper, had stumbled upon its secret.
